# %%
import json
import numpy as np
from collections import defaultdict
import evaluate
from rouge_score import rouge_scorer

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"  

import torch
import warnings

if hasattr(torch, 'cuda'):
    original_is_available = torch.cuda.is_available
    torch.cuda.is_available = lambda: False
    
    if hasattr(torch.cuda, 'device_count'):
        torch.cuda.device_count = lambda: 0
    
    warnings.warn("Running on Mac: CUDA support disabled, using CPU instead.")

device = torch.device('cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu
# /var/folders/2h/yzlph4251j1g9g7p_lrtn8f00000gn/T/ipykernel_19513/2225748465.py:22: UserWarning: Running on Mac: CUDA support disabled, using CPU instead.
#   warnings.warn("Running on Mac: CUDA support disabled, using CPU instead.")
# '\nif hasattr(torch, \'backends\') and hasattr(torch.backends, \'mps\') and torch.backends.mps.is_available():\n    device = torch.device("mps")\n    print(f"Apple Silicon detected! Updated device: {device}")\n'

# %%
# Use custom rouge function to obtain rouge 3/4 which are not available in huggingface
def get_rouge_score(gold, pred):
    rouge_scores = ['rouge1', 'rouge2', 'rouge3', 'rouge4', 'rougeL']
    scorer = rouge_scorer.RougeScorer(rouge_scores, use_stemmer=True)
    scores = scorer.score(gold, pred)
    return {k: scores[k].fmeasure * 100 for k in rouge_scores}

def compute_custom_metrics(srcs, golds, preds, device):
    scores = defaultdict(list)
    
    # For rouge and length go over examples one by one and determine mean
    for gold, pred in zip(golds, preds):
        for k, v in get_rouge_score(gold, pred).items():
            scores[k].append(v)
        scores['words'].append(len(pred.split(' ')))
    for k, v in scores.items():
        scores[k] = np.mean(v)

    
    return scores

def print_metrics_as_latex(metrics):
    # Print latex table row
    order = ['rouge1', 'rouge2', 'rouge3', 'rouge4', 'rougeL']
    print(' & '.join([f'${metrics[k]:.2f}$' for k in order]))

# %%
# Experiment 1 and 2
test_data_file = "/Users/kavyakarthi/Documents/MCS/CS598/Final_Project/Code/final_proj/gpt-4/summarization_data/exp_1_test.json"
# test_data_file = "/Users/kavyakarthi/Documents/MCS/CS598/Final_Project/Code/final_proj/gpt-4/summarization_data/exp_2_test.json"

preds_data_file = "/Users/kavyakarthi/Documents/MCS/CS598/Final_Project/Code/final_proj/gpt-4/summarization_results/gpt-4.1_exp1_results_prompt3_2shot.jsonl"
# preds_data_file = "/Users/kavyakarthi/Documents/MCS/CS598/Final_Project/Code/final_proj/gpt-4/summarization_results/gpt-4.1_exp1_results_prompt3.1_0shot.jsonl"
# preds_data_file = "/Users/kavyakarthi/Documents/MCS/CS598/Final_Project/Code/final_proj/gpt-4/summarization_results/gpt-4.1_exp2_results_prompt3_5shot.jsonl"
# preds_data_file = "/Users/kavyakarthi/Documents/MCS/CS598/Final_Project/Code/final_proj/gpt-4/summarization_results/gpt-4.1_exp2_results_prompt3.1_0shot.jsonl"


# Read jsonl files
def read_jsonl(file_name):
    with open(file_name, "r") as f:
        return [json.loads(line) for line in f]
    
# Read jsonl files
test_data = read_jsonl(test_data_file)
preds_data = read_jsonl(preds_data_file)

# %%
# Print included valid examples with indices
for i in range(0, 3):
    print(i)
    print(test_data[i]["text"])
    print(test_data[i]["summary"])
    print(preds_data[i]["summary"])
    print()
# Out:
# 0
# Name:  ___                 Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   M
#
# Service: MEDICINE
#
# Allergies:
# No Known Allergies / Adverse Drug Reactions
#
# Attending: ___
#
# Chief Complaint:
# Hematuria
#
# Major Surgical or Invasive Procedure:
# Right heart cardiac catheterization
#
# History of Present Illness:
# ___ male with past medical history significant for
# chronic diastolic heart failure, atrial fibrillation on
# warfarin, pulmonary hypertension, chronic kidney disease
# presents with hyperkalemia from his PCPs office but also with a
# multitude of complaints. Per OMR he has been admitted multiple
# times in the last month for CHF exacerbations the most recent
# admission being just a few days ago. He was diuresed and sent
# home. Yesterday he was seen in PCP's office with cc of
# hematuria. PCP did basic labs including lytes and recommended if
# it continues to refer to urology. Today the ___ physician
# was called by the lab who noted a K of 7.5 (hemolyzed) as well
# as creatinine of 2.1 (above baseline). ___ MD sent him
# to ___ for a recheck of the K.
# In the ___ here he c/o suprapubic abd pain, doe that is stable,
# dyuria and hematura which is new. VS on admission to ___: Neck
# supple, bibasilar rales, ___ SM throughout precordium, abd soft
# but TTP at suprapubic region, 2+ Pitting edema to knees. LAbs
# notable for ___ with creatinine 2.1 and UA with UTI with BNP at
# baseline. ECG revealed V-paced at 71bpm. Received Ciprofloxacin
# X 1. Admitted for UTI.
# .
# VS on transfer to floor: T:98.2 HR: 69, BP:112/74, 20 95RA
# .
# Per his daughter the patient has been on a roller coaster over
# the last few months with gradually worsening health and
# multitudes of health problems. Most recently he has had the
# hematuria. She reports working with the ___ clinic
# to ascertain the appropriate dose of coumadin for this and
# seeing the PCP as above. In addition she reports one day of
# dysuria and suprapubic pain that is chronic from his hernia and
# abdominal distension from the fluid retension of CHF. She
# reports no change in his lower extremity edema and no worsening
# of his DOE. She denies him having had fevers, or chills as does
# he. No other evidence of bleeding including no black or bloody
# stools.
# The patient also notes a ___ week history of right and left
# scapular pain and back pain which has been becoming more severe
# in recent weeks. He denies trauma to area. He denies changes in
# diet and reports compliance with medication.
# .
# On review of systems: He also notes itchiness which per OMR is
# chronic.
#
# Past Medical History:
# 1. Diabetes.
# 2. Dyslipidemia.
# 3. Hypertension.
# 4. Atrial fibrillation.
# 5. Hyperthyroidism
# 6. Anemia.
# 7. Dysphagia.
# 8. Arthritis.
# 9. Chronic kidney disease.
# 10. h/o cardiomyopathy
# 11. moderate-to-severe tricuspid regurgitation
# 12. diastolic heart failure
# 13. sick sinus syndrome with complete heart block s/p pacemaker
#
# 14. Pulmonary hypertension
#
# Social History:
# ___
# Family History:
# No family history of premature coronary artery disease or sudden
# death. Mother died of CVA. Father died of cancer. Son survived
# lymphoma.
#
# Physical Exam:
# ADMISSION:
# VS: T96.3, HR70, BP 110/70, RR16 100RA
# GENERAL: Alert, interactive, appropriate, no acute distress
# HEENT: Sclera anicteric. PERRL, EOMI. MMM.
# NECK: JVD elevated to jaw
# CARDIAC: RR, nl rate, III/VI murmur at RUSB.
# LUNGS: right base crackles otherwise CTAB
# ABDOMEN: distended with mild TTP in suprapubic region.
# EXTREMITIES: warm, 3+ edema to knees
# SKIN: heel ulcer, multiple ecchymosis
# .
# DISCHARGE PHYSICAL EXAMINATION:
# Admission weight 63.5kg Today 58.7Kg
# VS: T:97.8 P:62(62-89) BP:109/66(94-109/54-64) RR:18 SaO2:95%RA
#
# I/O: 1300/1775 + additional void, NR/1200 today
# .
# GENERAL: Elderly cachectic appearing male in NAD, no resp
# distress
# HEENT: MMM, anicteric sclera, PEERLA
# NECK: Supple with 8cm JVP
# CARDIAC: Grade ___ crecendo decrecendo murmur at RUSB, ___
# holosystolic murmur at the apex. faint S1, normal S2, irregular
#
# LUNGS: Decreased breath sounds on right faint ___ inspiratory
# rales. Dull to percussion at right base. no wheezes or rhonchi.
#
# ABDOMEN: Soft, mildly distended, nontender. Smooth liver border
# BS normo active.
# EXTREMITIES: Chronic venous stasis changes ___, 2cm diameter open
# skin lesion with clean granular base on medial aspect of right
# calve, dressing in place. Trace edema to the ankles ___.
# PULSES:
# Right: DP 1+ ___ 1+
# Left: DP 1+ ___ 1+
#
#
# Pertinent Results:
# ADMISSION LABS
# ___ 10:17PM BLOOD WBC-7.3 RBC-5.36 Hgb-11.7* Hct-37.5*
# MCV-70* MCH-21.7* MCHC-31.1 RDW-17.8* Plt ___
# ___ 10:17PM BLOOD Neuts-74.8* Lymphs-14.7* Monos-8.7
# Eos-1.3 Baso-0.5
# ___ 01:00AM BLOOD ___ PTT-39.1* ___
# ___ 10:17PM BLOOD Glucose-105* UreaN-82* Creat-2.1* Na-131*
# K-5.4* Cl-93* HCO3-28 AnGap-15
# ___ 02:00PM BLOOD ALT-25 AST-71* AlkPhos-151* TotBili-0.8
# ___ 02:00PM BLOOD Free T4-1.4
# ___ 02:00PM BLOOD TSH-0.12*
# .
# DISCHARGE LABS
# .
# ___ 06:40AM BLOOD WBC-7.0 RBC-4.43* Hgb-9.6* Hct-31.0*
# MCV-70* MCH-21.6* MCHC-30.9* RDW-18.2* Plt ___
# ___ 07:00AM BLOOD ___ PTT-38.1* ___
# ___ 06:40AM BLOOD Glucose-118* UreaN-78* Creat-1.8* Na-133
# K-3.1* Cl-88* HCO3-36* AnGap-12
# .
# ECHO ___
# The left atrium is dilated. The right atrium is markedly
# dilated. The estimated right atrial pressure is ___. Left
# ventricular wall thicknesses are normal. The left ventricular
# cavity size is normal. The left ventricular ejection fraction is
# moderately depressed (35%) secondary to mechanical dyssynchrony
# as well as right ventricular-centric septal motion. There is no
# left ventricular outflow obstruction at rest or with Valsalva.
# The right ventricular free wall is hypertrophied. The right
# ventricular cavity is markedly dilated with severe global free
# wall hypokinesis. There is abnormal septal motion/position
# consistent with right ventricular pressure/volume overload as
# well as pacing-induced dyssynchrony. The aortic valve leaflets
# are moderately thickened. Significant aortic stenosis is present
# (not quantified; however, the reduction od aortic valve orifice
# area is severe and probably represents low flow/low gradient
# aortic stenosis). The mitral valve leaflets are mildly
# thickened. There is no mitral valve prolapse. An eccentric,
# posteriorly directed jet of moderate (2+) mitral regurgitation
# is seen. Due to the eccentric nature of the regurgitant jet, its
# severity may be significantly underestimated (Coanda effect).
# The tricuspid valve leaflets are mildly thickened. Severe [4+]
# tricuspid regurgitation is seen. [In the setting of at least
# moderate to severe tricuspid regurgitation, the estimated
# pulmonary artery systolic pressure may be underestimated due to
# a very high right atrial pressure.] The main pulmonary artery is
# dilated. The branch pulmonary arteries are dilated. There is no
# pericardial effusion.
# .
# Compared with the findings of the prior report (images
# unavailable for review) of ___, the mitral and
# tricuspid regurgitation are increased, biventricular antegrade
# stroke volume is markedly reduced, and the low flow/low gradient
# nature of the aortic stenosis is now evident. The right
# ventricle is now significantly more dilated and hypocontractile.
#
# ................................................
# CARDIAC CATHETERIZATION ___
# Technical
# Anesthesia: Local
# Specimens: none
# RHC via RFV, 7 ___ PWP
# .
# Blood Oximetry Information
# Baseline
# TimeSiteHgb (gm/dL)Sat (%)
# 10:02AMPA      10.10          50
# 10:22AMART     10.10          93
# .
# 100% O2
# TimeSiteHgb (gm/dL)Sat (%)
# 10:33AMART     10.10          100
# 10:38AMPA      10.10          62
# 10:44AMRA      10.10          67
# .
# Cardiac Output Results
# Phase     C.O. (l/min)Fick C.I. (l/min/m2)(BPM)
# Baseline          3.56                    2.12
# 100% O2          4.03                    2.39
# .
# Hemodynamic Measurements (mmHg)
# Baseline
# SiteSysDiasEndMeanA WaveV WaveHR
# ___      ___
# PCW      ___
# ___      ___ O2
# SiteSysDiasEndMeanA WaveV WaveHR
# PCW      ___
# ___      ___      ___
# .
# Radiology Summary
# Total Cine Runs
# Fluoro Time (minutes)15.60
# Total IRP Dosage (mGy)137
# .
# Findings
# ESTIMATED blood loss: <100 cc
# Hemodynamics (see above):
# Assessment & Recommendations
# 1.Moderate pulmonary hypertension
# 2.Reduced cardiac output
# 3.Increased cardiac output with 100% O2 but no change in Mean
# PA
# pressure and an increase in left sided filling pressure with
# reduction of PVR from 359 dynes-sec/cm5 to 258 dynes-sec/cm5
#
#
# Brief Hospital Course:
# ___ male with past medical history significant for
# chronic diastolic heart failure, atrial fibrillation on
# warfarin, pulmonary hypertension, chronic kidney disease & sick
# sinus syndrome/CHB recently admitted to ___ ___ to ___ for
# congestive heart failure and generalized arthralgias which was
# attributed to methimazole is readmitted ___ for Urinary tract
# infection and found to have worsening congestive heart failure.
# .
# ACTIVE ISSUES
# =============
# # Acute on Chronic congestive heart failure with systolic and
# diastolic dysfunction: On admission, he complained of worsening
# abdominal distention and weight gain from 131 to 142lb. TTE in
# this admission shows worsened EF of 35% from 55% in ___ ___s septal dyssynchrony and worsening MR/TR. He as taken for
# right heart catheterization which showed moderate pulmonary
# hypertension and normal RV filling pressure, elevated RV
# systolic pressure. Right heart failure is attributed to left
# heart failure. Abdominal distention is related to right heart
# failure with ascites. He was treated with a furosemide drip
# augmented by metolazone with goal negative ___. At
# discharge, furosemide was discontinued and Torsemide 100mg Daily
# started. At discharge, his weight was 58.7kg, down from 63.5kg.
# He was discharged with a plan for pacemaker upgrade int ___
# weeks and will continue warfarin until then.
# .
# # Atrial fibrillation: warfarin was held for right heart cath
# and resumed at the  At the time of discharge, warfarin was held
# in anticipation of BiVentricular pacer upgrade and restarted on
# the day of discharge. He will have ___ check his INR.
# .
# # Urinary tract infection: Patient complained of dysuria and had
# recently been hospitalized with a foley catheter in place. Urine
# culture grew pan sensitive e. coli and he was treated with
# cefpodoxime x 10 days.
# .
# # Hematuria: related to foley and warfarin, resolved by HD 2
# with no significant blood loss.
# .
# INACTIVE ISSUES
# ==============
# # CORONARIES: Cath in ___ shows two vessel disease. He did not
# complain of chest pain, EKG did not show ischemic change.
# Continued medical management.
# - Continue Aspirin 81 mg PO/NG DAILY
# - Continue Metoprolol Tartrate 25 mg PO/NG BID
# - Continue Simvastatin 20 mg PO/NG DAILY
# .
# # RHYTHM: Ventricular pacing, with underlying atrial
# fibrillation therapeutic on warfarin, rate controled with
# metoprolol.
# .
# # Right foot abrasion: patient with two abrasions on right foot,
# no sign of infection. lateral lesion closed by the time of
# discharge, medial abrasion remained dressed but open.
# - Wound care consult
# .
# # Left calf muscle cramp: patient complained intermittantly of
# left calf ___ horse", exam did not show asymetric swelling,
# an area of induration over lateral left calf consistent with
# contracted muscle was paplated. Low suspicion for DVT as patient
# was therapeutic on warfarin on admission.
# .
# # Myalgias: patient with ___ shoulder pain and arm pain.
# previously attributed to reaction to methimazole.
# - Continue TraMADOL (Ultram) 25 mg PO Q6H:PRN
# - Continue Acetaminophen 650 mg PO/NG TID
# .
# # Anemia: Microcytic, last colonoscopy ___ shows normal colon
# to cecum. Previously attributed to CKD, previously on
# darvopoietin.
# - Continue Ferrous Sulfate 325 mg PO/NG DAILY
# - Continue Cyanocobalamin 1000 mcg PO/NG DAILY
# - Continue FoLIC Acid 1 mg PO/NG DAILY
# .
# # Hyperlipidemia Continue simvastatin as above
# .
# TRANSLATION OF CARE
# ===================
# Reasons for readmission
# - Poor monitoring of weight and salt intake leading to CHF
# exacerbation, he has ___ and daily weights but has accumlated
# >10lbs without intervention in the past.
# .
# # FULL CODE
# .
# # Contact: Daughter ___
#
# Medications on Admission:
# acetaminophen 1000mg TID
# aspirin 81 mg Tablet, Dailyu
# calcitriol 0.25 mcg Capsule One (1) Capsule by mouth ___,
# ___.
# cyanocobalamin (vitamin B-12) 1,000 mcg Tablet Extended Release
# One (1) Tablet Extended Release by mouth once a day.
# eplerenone 25 mg Tablet One (1) Tablet by mouth once a day
# ferrous sulfate 325 mg (65 mg Iron) Tablet One (1) Tablet by
# mouth once a day.
# fluticasone 50 mcg/Actuation Spray, Suspension One (1) spray
# Nasal once a day: in each nostril.
# folic acid ___ mcg Tablet One (1) Tablet by mouth once a day.
# furosemide 80 mg Tablet One (1) Tablet by mouth twice a day
# lorazepam 0.5 mg Tablet 0.5 Tablet by mouth once a day as needed
# for anxiety.
# metoprolol succinate 50 mg Tablet 1 Tablet by mouth DAILY
# naftifine 1 % Gel One (1) application Topical twice a day as
# needed for fungal infection
# repaglinide 0.5 mg Tablet One (1) Tablet by mouth twice a day
# simvastatin 20 mg TabletOne (1) Tablet by mouth once a day.
# tramadol 50 mg Tablet0.5 Tablet by mouth every six (6) hours as
# needed for pain.
# urea 40 % Gel One (1) application Topical once a day as needed
# for nail infection.
# warfarin 2.5 mg TabletOne (1) Tablet by mouth 3X/WEEK (___).
# warfarin 5 mg Tablet One (1) Tablet by mouth 5X/WEEK
# (___).
#
# Discharge Medications:
# 1. calcitriol 0.25 mcg Capsule Sig: One (1) Capsule PO 4X/WEEK
# (___).
# 2. eplerenone 25 mg Tablet Sig: One (1) Tablet PO DAILY (Daily).
#
# 3. fluticasone 50 mcg/Actuation Spray, Suspension Sig: One (1)
# Spray Nasal DAILY (Daily).
# 4. metoprolol succinate 50 mg Tablet Extended Release 24 hr Sig:
# One (1) Tablet Extended Release 24 hr PO once a day.
# 5. naftifine 1 % Gel Sig: One (1) appl Topical once a day as
# needed for apply to the nails twice a day as needed for fungal
# infection  .
# 6. repaglinide 0.5 mg Tablet Sig: One (1) Tablet PO twice a day.
#
# 7. simvastatin 20 mg Tablet Sig: One (1) Tablet PO once a day.
# 8. Urea 40 40 % Gel Sig: One (1) appl Topical once a day: apply
# to the nails once a day as needed for fungal infection  .
# 9. aspirin 81 mg Tablet, Delayed Release (E.C.) Sig: One (1)
# Tablet, Delayed Release (E.C.) PO once a day.
# 10. cyanocobalamin (vitamin B-12) 1,000 mcg Tablet Extended
# Release Sig: One (1) Tablet Extended Release PO once a day.
# 11. folic acid ___ mcg Tablet Sig: One (1) Tablet PO once a day.
#
# 12. acetaminophen 500 mg Tablet Sig: Two (2) Tablet PO three
# times a day: DO NOT EXCEED 4 GRAMS/DAY.
# 13. lorazepam 0.5 mg Tablet Sig: 0.5 Tablet PO once a day.
# 14. tramadol 50 mg Tablet Sig: 0.5 Tablet PO Q6H (every 6 hours)
# as needed for pain.
# 15. warfarin 2.5 mg Tablet Sig: One (1) Tablet PO 3x/WEEK (MWF).
#
# 16. warfarin 5 mg Tablet Sig: One (1) Tablet PO 4X/WEEK
# (___).
# 17. cefpodoxime 100 mg Tablet Sig: Two (2) Tablet PO Q24H (every
# 24 hours) for 2 days: Final day ___  .
# Disp:*4 Tablet(s)* Refills:*0*
# 18. torsemide 100 mg Tablet Sig: One (1) Tablet PO once a day.
# Disp:*30 Tablet(s)* Refills:*2*
# 19. Outpatient Lab Work
# INR check ___
# Report results to HCA Anticoagulation at tel ___
# 20. Outpatient Lab Work
# Electrolytes Na, K, Cl, HCO3, BUN, Cr, Mg ___
# Fax results to ___ ___ NP (___)
# 21. ferrous sulfate 325 mg (65 mg Iron) Tablet Sig: One (1)
# Tablet PO once a day.
#
#
# Discharge Disposition:
# Home With Service
#
# Facility:
# ___
#
# Discharge Diagnosis:
# Acute on Chronic congestive heart failure with diastolitc and
# systolic dycfunction LVEF 35%
# .
# Urinary tract infection
# Coronary artery disease
# Diabetes.
# Dyslipidemia.
# Hypertension.
# Atrial fibrillation.
# Anemia.
# Chronic kidney disease.
# sick sinus syndrome with complete heart block s/p pacemaker
# Pulmonary hypertension
#
#
# Discharge Condition:
# Mental Status: Confused - sometimes.
# Level of Consciousness: Alert and interactive.
# Activity Status: Ambulatory - requires assistance or aid (walker
# or cane).
# As you know, you were admitted because you were having blood in your urine which happened because you are on coumadin and had a foley catheter in your last hospital stay. You did not loose a significant amount of blood and bleeding resolved. We noted that you have a urinary tract infection which we are treating with antibiotics. You will need to continue taking antibiotics for 2 more days after leaving the hospital. We noted that you had a large amount of fluid in your stomach and treated you with medication (furosemide and metolazone) to decrease this fluid. We examined your heart using an ultrasound and noted that your heart does not squeeze as hard as it did a few months ago which is related to heart failure. We performed a cardiac catheterization to evaluate your heart failure and concluded that you would best benefit from changing your pacemaker.
# You were admitted with shortness of breath and cough due to lung cancer metastasis, requiring procedures like pericardial window creation and drainage for malignant pericardial effusion. You also had a pulmonary embolism and a right anterior/apical pneumothorax during your hospital stay. Upon discharge, you were stable with oxygen support and scheduled for outpatient follow-ups.
#
# You were admitted for nausea and vomiting, likely exacerbated by a hiatal hernia. Thoracic surgery recommended a fundoplication surgery for your hiatal hernia, which will be scheduled as an outpatient procedure. You were also managed for your chronic conditions like GERD, hypertension, and dyslipidemia during your hospitalization.
#
# Lastly, you were admitted for a urinary tract infection and worsening congestive heart failure with systolic and diastolic dysfunction. Your heart failure was managed with diuretics, and plans were made for a pacemaker upgrade in the future. You were also treated for anemia, atrial fibrillation, and other chronic conditions. Upon discharge, you were stable but required assistance with ambulation. Follow-up appointments and medication adjustments were arranged for your ongoing care.
#
# 1
# Name:  ___                 Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   M
#
# Service: MEDICINE
#
# Allergies:
# No Known Allergies / Adverse Drug Reactions
#
# Attending: ___.
#
# Chief Complaint:
# Hypotension, GI Bleed
#
#
# Major Surgical or Invasive Procedure:
# ___ endoscopy
#
# History of Present Illness:
# Mr. ___ is a ___ man with history of CAD on plavix
# and ASA, PVD, and HTN with recent admission for mesenteric
# ischemic s/p SMA stent complicated acute cholecystitis s/p
# percutaneous cholecystostomy and NSTEMI who presents with
# melena. Patient currently living at ___ where he was
# found to have black stools per his rectal tube for the past 1
# day. At rehab prior to transfer his vitals were T 100.5, BP
# 117/60, HR 85, RR 20, O2 sat 98% RA. The patient was going to be
# sent here however was diverted with EMS to be hypotensive and
# was seen at ___ initially. On arrival, his vitals were T 97.8,
# BP 122/50, HR 80, RR 18, O2 sat 98% on 3L. His vital remained
# stable but his BP drifted down to 100s/40s. He was given 80 mg
# Protonix bolus and started on a Protonix ggt as well as 20mg IV
# famotidine, 25mcg IV fentanyl, and 1L NS bolus. Labs were
# significant for WBC 16.4, H/H 7.1/23.3, BUN 65, Cr 1.46. He was
# given 1 unit PRBCs and was subsequently sent to this facility
# for further management. Per his wife, she notes his stool was
# brown yesterday but today it became black. He notes he is not
# not usually confused at baseline but becomes confused when he is
# anemic as well as when he receives multiple pain medications.
#
# In the ED, initial vitals: 98.3 94 111/53 20 100% Non-Rebreather
#
# - GI was consulted who recommended continuing PPI, PRBC
# transfusion, and NPO. They will continue to follow.
# - Vascular Surgery was consulted who recommended holding Plavix
# but continuing Aspirin 81mg.
# - Labs were significant for WBC 15.2 w/ 70% PMNs, H/H 7.3/23.5
# (baseline ___, plts 411, INR 1.3, lactate 1.3, Cr 1.3
# (baseline 1.1-1.3), ALT 112, AST 87, ALP 445, Tbili 1.3, trop
# 0.1. UA with small blood, large leuks, 24 RBCs, 133 WBCs,
# bacteruia.
# On transfer, vitals were: 99.0 96 130/62 25 100% RA
#
# On arrival to the MICU, patient complains of phantom leg pain.
#
# Review of systems:
# (+) Per HPI
# (-) Denies fever, chills, night sweats, recent weight loss or
# gain. Denies headache, sinus tenderness, rhinorrhea or
# congestion. Denies cough, shortness of breath, or wheezing.
# Denies chest pain, chest pressure, palpitations, or weakness.
# Denies nausea, vomiting, diarrhea, constipation, abdominal pain,
# or changes in bowel habits. Denies dysuria, frequency, or
# urgency. Denies arthralgias or myalgias. Denies rashes or skin
# changes.
#
#
# Past Medical History:
# Failure to thrive
# PVd,s/p rt. fem-pop
# hypertension
# ischemic heart disease, stable angina, s/p CABG's ___
# caroitd disease with occluded LICA and s/p Rt. CEA
# tobacco use, current 1ppd
# + stress with fixed inferolateral wall defect, no ischemia ___
# arthritis
# gout-uses colchicine prn
# postoperative delerium
# gastric reflux disease
# hyperlipdemia
# recent URi, resolving ___
# history of renal artery stenoisi s/p renal stenting with chronic
# renal disease stg ___
#
#
# Social History:
# ___
# Family History:
# unknown
#
# Physical Exam:
# ON ADMISSION
# Vitals: T: 98.6 BP: 112/83 P: 99 R: 22 O2: 100% RA
# GENERAL: Confused, moaning, complaining of leg pain
# HEENT: Sclera anicteric, MMM, oropharynx clear
# NECK: supple, JVP not elevated, no LAD
# LUNGS: Clear to auscultation bilaterally, no wheezes, rales,
# rhonchi
# CV: Regular rate and rhythm, normal S1 S2, no murmurs, rubs,
# gallops
# ABD: Soft, non-tender, non-distended, bowel sounds present, no
# rebound tenderness or guarding, no organomegaly, right
# percutaneous neprhostomy tube c/d/i
# EXT: Warm, well perfused, 2+ pulses, no clubbing, cyanosis or
# edema, right BKA
# SKIN: Unstageable sacral ulcer.
# RECTAL: Rectal tube in place with black guaiac positive stool.
# NEURO: A&Ox1 (name), moving all 4 extremities.
#
# ON DISCHARGE
#
# Vitals: T 98.2 (98.2), BP 130/63 (100/62-134/66), P 70 (62 -
# 72), R 16, O2 98% on RA
# I/O 24 hr yestesrday: 390/630+, since MN ___
# Drain outs: 200
# General: Alert, lying in bed in NAD
# HEENT: Sclera anicteric, MMM
# Neck: Right sided bruit and well healed endarterectomy scar
# noted, no left sided bruit.
# Lungs: Decreased breath sounds on right side compared to left,
# no crackles. otherwise CTAB,  No wheezes, bronchial breath
# sounds.
# CV: Regular rate and rhythm, normal S1 + S2, faint holosystolic
# murmur. no rubs, gallops
# Abdomen: Perc chole tube in RUQ with biluous drainage in tube.
# Insertion site without erythema/drainage/tenderness. Abdomen is
# soft, non-tender, non-distended, active bowel sounds present, no
# rebound tenderness or guarding, no organomegaly.
# Ext: Right sided BKA. Both extrem warm, well perfused, no
# clubbing, cyanosis or edema.  Right sided PICC.
# Skin: Unremarkable, no rashes noted. Some brusising at
# phlebotomy sites.
# Neuro: Facial movement intact, tongue protrusion midline
#
# Pertinent Results:
# ON ADMISSION
#
# ___ 09:55PM URINE  RBC-24* WBC-133* BACTERIA-FEW YEAST-MANY
# EPI-0
# ___ 09:55PM   WBC-15.2* RBC-2.50* HGB-7.3* HCT-23.5* MCV-94
# MCH-29.4 MCHC-31.3 RDW-16.9*
# ___ 09:55PM   ALT(SGPT)-112* AST(SGOT)-87* ALK PHOS-445*
# TOT BILI-1.3
# ___ 09:55PM   GLUCOSE-103* UREA N-62* CREAT-1.3* SODIUM-141
# POTASSIUM-4.6 CHLORIDE-116* TOTAL CO2-15* ANION GAP-15
# ___ 08:06AM   GLUCOSE-112* UREA N-56* CREAT-1.4* SODIUM-144
# POTASSIUM-5.1 CHLORIDE-117* TOTAL CO2-12* ANION GAP-20
#
# LABS ON DISCHARGE
#
# ___ 05:50AM BLOOD WBC-17.0* RBC-2.91* Hgb-8.9* Hct-28.0*
# MCV-96 MCH-30.5 MCHC-31.7 RDW-17.6* Plt ___
# ___ 12:00PM BLOOD Neuts-81.6* Lymphs-12.2* Monos-5.3
# Eos-0.5 Baso-0.3
# ___ 05:50AM BLOOD ___ PTT-28.0 ___
# ___ 05:50AM BLOOD Glucose-94 UreaN-39* Creat-1.7* Na-143
# K-4.7 Cl-112* HCO3-19* AnGap-17
# ___ 05:50AM BLOOD ALT-62* AST-37 AlkPhos-340* TotBili-1.2
# ___ 01:42AM BLOOD CK-MB-4 cTropnT-3.01*
# ___ 05:50AM BLOOD CK-MB-3 cTropnT-2.70*
# ___ 05:50AM BLOOD Calcium-8.6 Phos-4.7* Mg-2.2
#
# MICROBIOLOGY
# Time Taken Not Noted     Log-In Date/Time: ___ 8:03 am
#       URINE      ADDED TO SPEC ___ 10:13PM ___.
#
#                             **FINAL REPORT ___
#
#    URINE CULTURE (Final ___:
#       YEAST.    >100,000 ORGANISMS/ML..
#
# ___ 8:06 am URINE     Site: NOT SPECIFIED      Source:
# Line-picc.
#
#                             **FINAL REPORT ___
#
#    URINE CULTURE (Final ___:
#       YEAST.    >100,000 ORGANISMS/ML..
#
# ___ 8:37 am SEROLOGY/BLOOD      ADD TO: ___.
#
#                             **FINAL REPORT ___
#
#    HELICOBACTER PYLORI ANTIBODY TEST (Final ___:
#       EQUIVOCAL BY EIA.
#            (Reference Range-Negative).
#       NOTE: Equivocal serologic test findings may be resolved
# through use
#       of the alternative, H. pylori stool antigen test.
#
# ___ 7:00 pm BLOOD CULTURE      Source: Line-right picc.
#
#                             **FINAL REPORT ___
#
#    Blood Culture, Routine (Final ___:    NO GROWTH.
#
# ___ 8:53 pm BLOOD CULTURE
#
#                             **FINAL REPORT ___
#
#    Blood Culture, Routine (Final ___:    NO GROWTH.
#
# ___ 7:44 am STOOL     CONSISTENCY: WATERY      Source:
# Stool.
#
#                             **FINAL REPORT ___
#
#    C. difficile DNA amplification assay (Final ___:
#       Negative for toxigenic C. difficile by the Illumigene DNA
#       amplification assay.
#            (Reference Range-Negative).
#
# REPORTS
#
# CT HEAD WITHOUT CONTRAST  (___)
#
# FINDINGS:
#
# There is no acute intracranial hemorrhage, edema, mass effect,
# or loss of
# gray/ white matter differentiation. There are foci of low
# density in the
# subcortical, deep, and periventricular white matter of the
# cerebral
# hemispheres, likely sequela of chronic small vessel ischemic
# disease in a
# patient of this age. There is moderate cerebral atrophy with
# associated
# prominence of the ventricles and sulci. No significant interval
# change is seen
# in the intracranial compartment compared to ___.
#
# Right mastoid has no pneumatized air cells, only a pneumatized
# antrum. There is an near-complete opacification of the right
# middle ear cavity and mastoid antrum, as well as fluid in the
# left mastoid antrum and left mastoid air cells, new compared to
# ___. There is also mild mucosal thickening in
# bilateral anterior ethmoid air cells and in bilateral sphenoid
# sinuses along the sphenoid septum, similar to prior.
#
# IMPRESSION:
#
#
# 1. No acute intracranial hemorrhage and no evidence for other
# acute
# intracranial abnormalities.
# 2.  Near-complete opacification of the right middle ear cavity
# and mastoid antrum. Fluid in the left mastoid antrum and mastoid
# air cells.  While there is no evidence for osseous destruction
# to suggest aggressive mastoiditis, please correlate clinically
# with any infectious symptoms.
#
# The study and the report were reviewed by the staff radiologist.
#
# CXR ___
#
# IMPRESSION:
#
# Right PICC tip is in themid SVC. There is moderate stable
# cardiomegaly. Aside from minimal right lower lobe atelectasis,
# the lungs are clear.  There is no pneumothorax or pleural
# effusion.  Sternal wires are aligned. Patient is status post
# CABG. There are low lung volumes.
#
# Cardiovascular Report ECG Study Date of ___  8:20:48 AM
#
# Sinus rhythm. Delayed precordial R wave progression. Diffuse ST
# segment
# depressions concerning for myocardial ischemia. Clinical
# correlation is
# suggested. Compared to the previous tracing of ___ the ST
# segment
# depressions diffusely are slightly more pronounced.
#
#   Intervals Axes
# Rate PR QRS QT/QTc P QRS T
# 85 ___ 34 2 174
#
#
# DUPLEX AND DOPPLER OF ABDOMEN (SMA STENT) ___
# IMPRESSION:
# 1. Extremely limited exam as patient was unable to hold his
# breath during the
# study. The SMA stent is noted with some flow, however, stenosis
# and direction
# of blood flow could not be assessed. If necessary, a CTA can be
# performed for
# further assessment.
# 2. Large, subcapsular hematoma
#
# T-TUBE CHOLANGIO (POST-OP) ___
# IMPRESSION:
#
# 1. Cholecystostomy tube is patent.
# 2. Normal filling of the gallbladder, cystic duct, common
# hepatic duct and
# CBD.
#
#
#
#
# Brief Hospital Course:
# Mr. ___ is a ___ man with history of CAD on plavix
# and ASA, PVD, and HTN with recent admission for mesenteric
# ischemic s/p SMA stent complicated acute cholecystitis s/p
# percutaneous cholecystostomy and NSTEMI who presents with
# melena.
#
# # GI Bleed: Patient was having melena per his rectal tube for
# the last 1 day upon admission to hospital. Given melena concern
# for upper GI bleed vs. slow lower GI bleed. Patient had known
# history of cirrhosis or varices. He was transferred to MICU for
# monitoring, and had 2 superficial ulcers  found in the duodenal
# bulb which were clean based and not actively bleeding. Given
# history of mesenteric ischemia s/p SMA stent, vascular surgery
# was also consulted, who plannd for a duplex SMA on ___ which
# was limited ___ patient unable to hold his breath during study.
#  Patient's blood count stabilized.  Patient's bleed was thought
# to have been provoked by plavix initiation after stent placement
# after last hospitalization.  Plavix was discontinued this
# admission after discussion with cardiology and family re:risks
# and benefits of plavix.
#
# # Acute Cholecystitis s/p percutaneous cholecystostomy: During
# recent admission had elevated WBC in setting of abdominal pain
# with positive HIDA. On admission patient had no abdominal pain.
# LFT's and fever curve were trended in house, and given lack of
# infectious symptoms, empiric antibiotics were not started.
# Patient was pan cultured on ___, which showed yeast on urine
# culture, and blood cx pending as of ___. Given uptrending
# LFT's and bilirubin, percutaneous cholecystostomy drain study
# was ordered which showed patent cholecystostomy tube, and normal
# filling of the gallbladder, cystic duct, common hepatic duct and
# CBD. Discussion with patient, family and surgery where it was
# decided that patient would have his tube in place and bag
# changed daily. Once output decreased to 50cc of fluid a day, can
# make appointment with surgery to have this removed.  This was
# decided with the family given the difficulty of transporting him
# from home.  The visiting hospice nurse with ___ the wound
# every ___ days; dresssing changes with a drain sponge.
#
# # Leukocytosis: Persistently elevated since her previous
# admission with a normal differential. No current signs or
# symptoms of infection. Patient had ceftriaxone started ___
# leukocyte positive U/A on ___. Patient had 1 X blood cx on
# ___ which did not grow out any organisms and urine culture
# sent on ___ which grew out yeast. Ceftriaxone was discontinued
# on ___ after aforementioned urine culture result.
#
# # Sterile pyuria: As above. UA with leuks and WBCs but negative
# nitrite likely in the setting of chronic indwelling foley.
# Patient denied any urinary symptoms on admission, likely
# representing asymptomatic bacteruria. Foley was discontinued on
# ___ and despite difficult foley removal, patient was
# voiding well without any symptoms.
#
# # Elevated Troponin: Elevated on admission to 0.1, initially
# though to be likely downtrending from his NSTEMI several weeks
# ago which peaked to 1.68 on ___. Denied current chest pain
# and EKG with acute ST or T wave changes in house. Troponins were
# trended in house, which initially held stable at 0.1. On ___
# the patient complained of chest pain. EKG showed new ST
# depressions in inferolateral leads and troponin was .8.
# Cardiology was consulted and it was noted patient was suffering
# new NSTEMI. Per cardiology, the presentation was most consistent
# with supply-demand mismatch due to anemia and compensatory
# tachycardia in the setting of fixed coronary artery disease. As
# a result, patient was set with a transufsion goal hgb > 9,
# increased to metoprolol 75mg TID.  Patient's troponins peaked in
# the mid-3s and started to downtrend on ___.
#
# #GOC: Patient explicitly stated on the floor that he wanted to
# go home and be comfortable and spend time with his family.  He
# did not want any more interventions.  Patient's wife (HCP) and
# the primary team agreed that patient was mentating well when
# expressing these feelings and capable of making this decision.
# As a result palliative care were consulted and patient and
# family elected to go home with hospice.
#
# # Phantom Limb Pain secondary to right BKA: Continued cymbalta,
# gabapentin, oxycodone for pain in house.  Plan on discharge, per
# palliative care, was to taper the gabapentin as it was not
# helping his pain.
#
# # CKD: Cr 1.3 on admission which appeared to be at baseline.
#
# # Severe Peripheral Vascular Disease: History right BKA, renal
# artery stenosis, carotid endarterectomy/stenting and recent
# mesenteric ischemia s/p SMA stent. Per vascular and cardiology
# recommendations, as well as discussion with palliative care and
# the family, held plavix and continued aspirin.
#
# # Hypertension: Given GI bleed, held home antihypertensives in
# house initially. With NSTEMI per above, started metoprolol 75 mg
# TID, and resumed imdur on ___.
#
# # CAD s/p CABG and NSTEMI: Per vascular recommendations,
# continued home ASA and held home plavix in house.
#
# TRANSITIONAL ISSUES:
# - Plavix was held (discussion with family with regards to risks
# of being on plavix causing bleeding and not being on plavix
# would put him at risk of stenosis of his stents, and family
# opted for not being on plavix), ASA 81mg was continued
# - He is being transitioned to home hospice
# - Please monitor perc cholecystostomy drain ouput and make
# appointment with surgery once drain output decreases to less
# than 50ml of fluid/day
# - patient's olanzapine was held in-house given liver function
# derangement, can consider restarting if needed
#
#
# Medications on Admission:
# The Preadmission Medication list is accurate and complete.
# 1. Acetaminophen 500 mg PO Q6H:PRN pain
# 2. OxycoDONE (Immediate Release)  5 mg PO Q6H:PRN pain
# 3. TraMADOL (Ultram) 50 mg PO Q4H:PRN pain
# 4. Artificial Tears ___ DROP BOTH EYES Q12H:PRN dry eyes
# 5. Bisacodyl 10 mg PO DAILY:PRN constipation
# 6. LOPERamide 2 mg PO QID:PRN diarrhea
# 7. Albuterol Inhaler 2 PUFF IH Q4H:PRN shortness of breath,
# wheezing
# 8. Polyethylene Glycol 17 g PO DAILY:PRN constipation
# 9. Senna 17.2 mg PO DAILY:PRN constipation
# 10. Bisacodyl 10 mg PR HS:PRN constipation
# 11. Aspirin 325 mg PO DAILY
# 12. Clopidogrel 75 mg PO DAILY
# 13. Duloxetine 20 mg PO BID
# 14. Gabapentin 600 mg PO TID
# 15. Lansoprazole Oral Disintegrating Tab 30 mg PO BID
# 16. Lidocaine 5% Patch 1 PTCH TD QAM
# 17. Metoprolol Succinate XL 100 mg PO BID
# 18. Mirtazapine 15 mg PO HS
# 19. OLANZapine 2.5 mg PO BID
# 20. Psyllium 1 PKT PO TID:PRN constipation
# 21. Amlodipine 5 mg PO DAILY
# 22. Multivitamins 1 TAB PO DAILY
# 23. Heparin 5000 UNIT SC TID
# 24. Cholestyramine 4 gm PO BID
# 25. Dronabinol 2.5 mg PO BID
# 26. Lisinopril 40 mg PO DAILY
# 27. Tamsulosin 0.4 mg PO HS
# 28. Isosorbide Mononitrate 60 mg PO DAILY
# 29. Insulin SC
#       Sliding Scale
# Insulin SC Sliding Scale using Novolog Insulin
#
#
# Discharge Medications:
# 1. HYDROmorphone (Dilaudid) ___ mg PO Q2H:PRN pain, shortness of
# breath
# RX *hydromorphone [Dilaudid] 1 mg/mL ___ ml by mouth Q2HR
# Refills:*0
# 2. Lorazepam 0.5-1 mg PO Q6H:PRN anxiety
# RX *lorazepam 2 mg/mL 0.25-0.5 mL by mouth Q6HR Refills:*1
# 3. Acetaminophen 650 mg PO Q6H:PRN pain
# 4. Aspirin 81 mg PO DAILY
# 5. Duloxetine 20 mg PO BID
# 6. Gabapentin 300 mg PO HS Duration: 5 Days
# Please give 300mg PO QHS ___ and then D/C gabapentin.
# 7. Isosorbide Mononitrate (Extended Release) 60 mg PO DAILY
# 8. Lidocaine 5% Patch 1 PTCH TD QAM
# 9. Senna 17.2 mg PO DAILY:PRN constipation
# 10. Docusate Sodium 100 mg PO BID:PRN constipation
# RX *docusate sodium 50 mg/5 mL 10 ml by mouth twice a day
# Refills:*1
# 11. Metoprolol Tartrate 75 mg PO TID
# RX *metoprolol tartrate 25 mg 3 tablet(s) by mouth Q8HR Disp
# #*180 Tablet Refills:*1
# 12. Nitroglycerin SL 0.4 mg SL Q5MIN:PRN chest pain
# RX *nitroglycerin 0.4 mg 1 tablet(s) sublingually every 5
# minutes as needed for chest pain x 3 doses (over 15 minutes)
# Disp #*20 Tablet Refills:*1
# 13. Pantoprazole 40 mg PO Q24H
# RX *pantoprazole 40 mg 1 tablet(s) by mouth daily Disp #*30
# Tablet Refills:*1
# 14. Albuterol Inhaler 2 PUFF IH Q4H:PRN shortness of breath,
# wheezing
# 15. Artificial Tears ___ DROP BOTH EYES Q12H:PRN dry eyes
# 16. Bisacodyl 10 mg PO DAILY:PRN constipation
# 17. Bisacodyl 10 mg PR HS:PRN constipation
# 18. Dronabinol 2.5 mg PO BID
# 19. Mirtazapine 15 mg PO HS
# 20. Tamsulosin 0.4 mg PO HS
# 21. haloperidol lactate 0.5-1 mg oral Q6H:PRN agitation
# RX *haloperidol lactate 2 mg/mL 0.25-0.5 ml by mouth every six
# (6) hours Refills:*2
#
#
# Discharge Disposition:
# Home With Service
#
# Facility:
# ___
#
# Discharge Diagnosis:
# GI Bleed
# NSTEMI
#
#
# Discharge Condition:
# Mental Status: Confused - frequently.
# Level of Consciousness: Alert and interactive.
# Activity Status: Out of Bed with assistance to chair or
# wheelchair.
# You were admitted for bleeding from your gastrointestinal tract, which was noticed due to you having dark, tarry stools. This was likely related to ulcers seen on endoscopy in addition to the anti-platelet medication you were on. You were given blood transfusions and the medication Plavix (an anti-platelet medication) was stopped. Your bleeding stopped and your blood counts remained stable. During your bleed, you had a heart attack similar to the heart attack last month. This was managed with medications to control your heart rate. After ongoing discussion with you, your family, and the Palliative Care team, it was decided that getting you home to spend time with your family with hospice was the most important goal for you. To help keep you comfortable, outpatient palliative care and home nursing are being set up. We are glad to see you head home to spend time with your family.
# You were admitted with shortness of breath and cough due to lung cancer metastasis, with a history of pericardial effusion and DVTs. You underwent procedures to drain fluid around your heart and lungs, and a pleurx catheter was placed. You were also diagnosed with a pulmonary embolism and treated with anticoagulants. Upon discharge, you were stable with oxygen support and scheduled for outpatient follow-up.
#
# 2
# Name:  ___                     Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   M
#
# Service: MEDICINE
#
# Allergies:
# Iodine; Iodine Containing
#
# Attending: ___.
#
# Chief Complaint:
# Dyspnea on exertion
#
# Major Surgical or Invasive Procedure:
# None
#
#
# History of Present Illness:
# ___ year old male with obesity, DM2, h/o Fournier's gangrene
# ___, and PE in ___ on coumadin, presents with dyspnea on
# exertion, noted today after he climbed the stairs at from the T.
# On further questioning, this has been going on for 2 weeks and
# is assoiciated with dizziness and weakness. His history is
# notable for a PE in the post-operative setting when he had
# colostomy take down in ___ (colostomy initially placed in
# ___ for fournier's gangrene. He is therapeutic on coumadin. He
# denies chest pain, cough, or fever/chills. He does admit to
# palpitations and of note, he was noted to be tachycardic to 120
# at a recent PCP visit, with unclear etiology at this time.
#
# In the ED, initial vitals were 113/88, HR 124, RR 34, 100% 2L.
# CXR revealed increase in vascular markings although BNP was wnl
# at 23. His Hct is 32, but this is his baseline. ECG and cardiac
# enzymes were negative for evidence of cardiac ischemia. There
# was concern for PE despite fact he is therapeutic on coumadin,
# and he was ordered a V/Q scan given his allergy to iodine
# contrast. This has not yet been done. His HR improved to 106 and
# RR improved to 16 with 4mg morphine. He also received ASA 325.
#
#
# Past Medical History:
# Fournier's Gangrene: s/p repair with colostomy
# Colostomy Revision: ___
# Pulmonary Embolus: ___, PostOp complication
# Hypertension
# Diabetes Type II, Insulin Requiring
# Anxiety
# Hyperlipidemia
#
# Social History:
# ___
# Family History:
# Relatives with COPD, MS, ovarian CA, uterine CA, bladder CA,
# mother and uncle with diabetes mellitus II, aunt with SLE,
# mother has hidradenitis ___. No known family history of
# early coronary artery disease or lipid/cholesterol problems.
#
# Physical Exam:
# Vitals: 131/91, 107, 22, 100% on RA
# GEN: Overweight gentleman, lying in bed, unkempt
# HEENT: EOMI, sclerae anicteric, dry MM, OP clear
# NECK: Obese, could not appreciate JVD but limited by body
# habitus
# COR: Tachycardic, distant heart sounds, regular rhythm
# PULM: CTAB
# ABD: Obese, NT, ND. Surgical dressing in LLQ
# EXT: No edema
# GU: R groin drain from abscess
#
#
# Pertinent Results:
# ___ 08:00AM BLOOD WBC-5.2 RBC-UNABLE TO  Hgb-10.8* Hct-35*
# MCV-UNABLE TO  MCH-UNABLE TO  MCHC-33.9 RDW-UNABLE TO  Plt
# ___
# ___ 04:00PM BLOOD Neuts-72.0* ___ Monos-5.3 Eos-2.2
# Baso-0.5
# ___ 08:00AM BLOOD ___ PTT-34.7 ___
# ___ 08:00AM BLOOD Glucose-140* UreaN-15 Creat-0.7 Na-141
# K-4.2 Cl-98 HCO3-28 AnGap-19
# ___ 08:00AM BLOOD CK(CPK)-81
# ___ 08:00AM BLOOD CK-MB-NotDone cTropnT-<0.01
# ___ 02:00AM BLOOD CK-MB-NotDone cTropnT-<0.01
# ___ 04:00PM BLOOD cTropnT-<0.01
# ___ 04:00PM BLOOD CK-MB-5 proBNP-23
# ___ 08:00AM BLOOD Calcium-8.5 Phos-3.5 Mg-1.8
#
# ECG: sinus tach at 106-___hanges or acute ischemia.
#
#
# Chest x-ray: Lungs are clear with no focal consolidation,
# pneumothorax, effusion, or sign of heart failure
#
# ECHO ___:
# The left atrium is mildly dilated. Left ventricular wall
# thickness, cavity size and regional/global systolic function are
# normal (LVEF >55%) Transmitral Doppler and tissue velocity
# imaging are consistent with normal LV diastolic function. Right
# ventricular chamber size and free wall motion are normal. The
# ascending aorta is mildly dilated. The aortic valve leaflets (3)
# appear structurally normal with good leaflet excursion and no
# aortic regurgitation. No masses or vegetations are seen on the
# aortic valve. The mitral valve appears structurally normal with
# trivial mitral regurgitation. There is no mitral valve prolapse.
# No mass or vegetation is seen on the mitral valve. The estimated
# pulmonary artery systolic pressure is normal. There is a
# trivial/physiologic pericardial effusion.
#
#
# Brief Hospital Course:
# Mr. ___ is a ___ year old gentleman with a PMH significant for
# Forniere's gangrene, presumed PE, and DM 2 admitted for sinus
# tachycardia and dyspnea on exertion.
#
# 1. Dyspnea on exertion/sinus tachycardia: Uncertain etiology at
# this time. Patient at low risk for PE with his therapeutic INR.
# Given subacute course of 2 weeks of dyspnea on exertion and
# tachycardia, this is unlikely to tamponade. Patient is not
# anemic below baseline and has a normal TSH.  In the ED, there
# was concern of ACS given that patient is a diabetic, but he did
# not have ECG changes concerning for ischemia and CE negative x3.
#  Patient had a stress test that did not demonstrate significant
# anginal or ischemic changes.
#
# 2. Pulmonary embolus: Patient with respiratory failure s/p
# operative procedure attributed to pulmonary embolus but
# unconfirmed as patient has allergy to iodine.  Patient was
# continued on coumadin during admission with goal INR between
# ___.
#
# 3. DM 2: Continued on home ___ regimen and HISS during
# admission.
#
# 4. Abscess: Patient had dressing changes during his admission.
#
# 5. HTN: Continued on valsartan, lisinopril, and toprol during
# hospital course.
#
# 6. Hypertriglyceridemia: Continued on simvastatin and
# fenofibrate during hospital course.
#
# 7. Psoriatic arthritis: Continued on sulfasalazine during
# hospital course.
#
# 8. Depression: Continued on lexapro during hospital course.
#
# Medications on Admission:
# Lexapro 40 mg daily
# Fenofibrate 145 mg daily
# Humalog sliding scale
# NPH/Humalog 72/25, 100 units qAM, 50 units qPM
# Lisinopril 40 mg daily
# Toprol XL 200 mg daily
# Simvastatin 40 mg daily
# Valsartan 80 mg daily
# Clotrimazole 1% cream to abdomen daily
# Sulfasalazine 1000mg po BID
# Oxycodone 5mg po BID prn pain
# Coumadin 5mg on MWF and 7.5mg on T,Th, Sa, ___
#
# Discharge Medications:
# 1. Escitalopram 10 mg Tablet Sig: Four (4) Tablet PO DAILY
# (Daily).
# 2. Fenofibrate Micronized 145 mg Tablet Sig: One (1) Tablet PO
# Daily ().
# 3. Insulin Lispro 100 unit/mL Cartridge Sig: Per home sliding
# scale  Subcutaneous  .
# 4. Insulin Lispro Protam & Lispro 100 unit/mL (75-25) Suspension
# Sig: 100 units QAM, 50 units QHS  Subcutaneous  .
# 5. Lisinopril 20 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily).
#
# 6. Metoprolol Succinate 100 mg Tablet Sustained Release 24 hr
# Sig: Two (2) Tablet Sustained Release 24 hr PO DAILY (Daily).
# 7. Simvastatin 40 mg Tablet Sig: One (1) Tablet PO DAILY
# (Daily).
# 8. Valsartan 40 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily).
#
# 9. Clotrimazole 1 % Cream Sig: One (1) application Topical twice
# a day.
# 10. Sulfasalazine 500 mg Tablet Sig: Two (2) Tablet PO BID (2
# times a day).
# 11. Oxycodone 5 mg Tablet Sig: One (1) Tablet PO BID (2 times a
# day) as needed for pain.
# 12. Warfarin 7.5 mg Tablet Sig: One (1) Tablet PO 4X/WEEK
# (___).
# 13. Warfarin 5 mg Tablet Sig: One (1) Tablet PO 3X/WEEK
# (___).
#
#
# Discharge Disposition:
# Home
#
# Discharge Diagnosis:
# Primary - Shortness of breath - deconditioning
#
# Secondary
# 1. Type 2 diabetes.
# 2. History of Fournier's gangrene, status post multiple surgical
#
# resections in early ___. Colostomy reversal in ___ complicated
# by PE and MRSA bacteremia.
# 3. H/o Pancreatitis secondary to hypertriglyceridemia
# 4. Psoriatic arthritis.
# 5. Depression status post recent suicide attempt and psychiatric
#
# inpatient admission.
# 6. Hyperlipidemia and Hypertriglyceridemia.
# 7. MRSA bacteremia in ___ vancomycin/Linezolid
# course because of ___ issues
# 8. PE in ___ (presumed--contrast allergy, became acutely
# hypoxic on the floor and required intubation)
# 9. ___ -Abscesses: one in LLQ and one in R groin, which has a
# drain in place. These are followed by surgery at ___
# 10. Hypertension
# 11. Urinary incontinence, undergoing work-up
# 12. Narcotics contract
#
# Discharge Condition:
# Patient discharged in stable condition.  he denies shortness of
# breath, ambulating without difficulty.
#  You were admitted for dyspnea on exertion and a fast heart rate. We determined that you were not having a heart attack during your admission. You also had a stress test during your admission. There was no evidence of coronary artery disease. You dyspnea is likely due to deconditioning. You should continue to exercise daily with a goal of losing ___ pounds.
# You were admitted with shortness of breath and cough, and were found to have fluid around your lungs and heart. Procedures were done to drain the fluid from around your heart into your lung space, and a drain was placed in the lung space to manage the fluid. You will need to have this fluid drained every few days. Upon discharge, you were stable with oxygen support and scheduled for outpatient cardiology follow-up.
#
# You were admitted for nausea and vomiting, likely due to viral gastroenteritis exacerbating your acid reflux disease. Thoracic surgery recommended a fundoplication surgery for your hiatal hernia, which will be scheduled as an outpatient procedure. You were discharged with medications to manage your conditions and instructions to follow up for surgery scheduling.
#
# You were admitted for dyspnea on exertion and sinus tachycardia. The cause was uncertain, but investigations ruled out significant issues. You had a stress test that did not show significant problems. You were continued on medications for your various conditions and discharged in stable condition. Follow-up was recommended for ongoing management.

# %%
srcs = [e["text"] for e in test_data]
golds = [e["summary"] for e in test_data]
preds = [e["summary"] for e in preds_data]
metrics_test = compute_custom_metrics(srcs, golds, preds, device)

metrics_test = {k: round(v, 2) for k, v in metrics_test.items()}
print("Test metrics rounded:")
print(metrics_test)
print_metrics_as_latex(metrics_test)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Test metrics rounded:
# {'rouge1': 27.56, 'rouge2': 6.24, 'rouge3': 1.83, 'rouge4': 0.47, 'rougeL': 16.39, 'words': 141.55, 'bert_score': 81.82, 'bert_score_deberta-large': 54.07, 'sari': 40.04}
# $27.56$ & $6.24$ & $1.83$ & $0.47$ & $16.39$ & $81.82$ & $54.07$ & $40.04$ & $141.55$
